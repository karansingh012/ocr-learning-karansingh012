# %% [markdown]
# # Face and object detection process

# %% [markdown]
# ## https://github.com/opencv/opencv/tree/master/data/haarcascades

# %%
#  
# Pre-trained classifiers for object detection using Haar Cascades
#
