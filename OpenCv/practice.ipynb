# %%
import cv2
import numpy as np
img = cv2.imread('/Users/karansingh/ocr-learning/OpenCv/fruit1.png')
if img is not None:
    cv2.imshow('Image', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Image not found")

# %%
import cv2 
img = cv2.imread('/Users/karansingh/ocr-learning/OpenCv/fruit1.png')
if img is not None:
    sucess = cv2.imwrite('/Users/karansingh/ocr-learning/OpenCv/fruit_saved.png', img)
    if sucess:
        print("Image saved successfully")
    else:
        print("Error in saving image")
else:
    print("Image not found")
# Out:
# Image saved successfully

# %%
import cv2
img = cv2.imread('/Users/karansingh/ocr-learning/OpenCv/fruit1.png')
if img is not None:
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) ## convert to grayscale
    success = cv2.imwrite('/Users/karansingh/ocr-learning/OpenCv/fruit_gray.png', gray_img)
    cv2.imshow('Image',gray_img)
    cv2.waitKey(0)
else:
    print("Image not found")
