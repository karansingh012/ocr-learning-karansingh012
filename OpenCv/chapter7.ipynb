# %% [markdown]
# # Contours & shape detections

# %% [markdown]
# * Finding & Drawing Contours in opencv

# %%
# contours jissme same color and same intensity ke points connected hote hai 
# contours ka use shape analysis , object detection and recognition me hota hai
# contours ko find krne ke liye image binary honi chahiye
# contours ko find krne ke liye opencv me findContours() function ka use hota hai
# contours ko draw krne ke liye drawContours() function ka use hota hai
# contours ko approximate krne ke liye approxPolyDP() function ka use hota hai
# contours ke moments ko calculate krne ke liye moments() function ka use hota hai
# contours ke area ko calculate krne ke liye contourArea() function ka use hota hai
# contours ke perimeter ko calculate krne ke liye arcLength() function ka use hota hai
# contours ke bounding rectangle ko calculate krne ke liye boundingRect() function ka use hota hai
# contours ke minimum enclosing circle ko calculate krne ke liye minEnclosingCircle() function ka use hota hai
# contours ke convex hull ko calculate krne ke liye convexHull() function ka use hota hai
# contours ke fit ellipse ko calculate krne ke liye fitEllipse() function ka use hota hai
# contours ke fit line ko calculate krne ke liye fitLine() function ka use hota hai
# contours ke hierarchy ko calculate krne ke liye findContours() function ka use hota hai   # contours ke approximation method ko specify krne ke liye findContours() function me parameter pass krte hai
# contours ke retrieval mode ko specify krne ke liye findContours() function me parameter pass krte hai
# contours ke drawing mode ko specify krne ke liye drawContours() function me parameter pass krte hai
# contours ke color ko specify krne ke liye drawContours() function me parameter pass krte hai
# contours ke thickness ko specify krne ke liye drawContours() function me parameter pass krte hai
# contours ke line type ko specify krne ke liye drawContours() function me parameter pass krte hai
# contours ke max level ko specify krne ke liye drawContours() function me parameter pass krte hai
# contours ke offset ko specify krne ke liye drawContours() function me parameter pass krte hai 
# contours ke approximation accuracy ko specify krne ke liye approxPolyDP() function me parameter pass krte hai
# contours ke fit ellipse ke parameters ko specify krne ke liye fitEllipse() function me parameter pass krte hai
# contours ke fit line ke parameters ko specify krne ke liye fitLine() function me parameter pass krte hai
# contours ke convex hull ke parameters ko specify krne ke liye convexHull() function me parameter pass krte hai
# contours ke bounding rectangle ke parameters ko specify krne ke liye boundingRect() function me parameter pass krte hai
# contours ke minimum enclosing circle ke parameters ko specify krne ke liye minEnclosingCircle() function me parameter pass krte hai
# contours ke moments ke parameters ko specify krne ke liye moments() function me parameter pass krte hai
# contours ke area ke parameters ko specify krne ke liye contourArea() function me parameter
# contours ke perimeter ke parameters ko specify krne ke liye arcLength() function me parameter pass krte hai
# contours ke hierarchy ke parameters ko specify krne ke liye findContours() function me parameter pass krte hai
# contours ke image ke parameters ko specify krne ke liye findContours() function me parameter pass krte hai
# contours ke retrieval mode ke parameters ko specify krne ke liye findContours() function me parameter pass krte hai
# contours ke approximation method ke parameters ko specify krne ke liye findContours() function me
# contours ke drawing mode ke parameters ko specify krne ke liye drawContours() function me parameter pass krte hai
# contours ke color ke parameters ko specify krne ke liye drawContours() function me parameter pass krte hai
# contours ke thickness ke parameters ko specify krne ke liye drawContours() function me parameter
# contours ke line type ke parameters ko specify krne ke liye drawContours() function me parameter pass krte hai
# contours ke max level ke parameters ko specify krne ke liye drawContours() function me
# contours ke offset ke parameters ko specify krne ke liye drawContours() function me parameter pass krte hai
# contours ke approximation accuracy ke parameters ko specify krne ke liye approxPolyDP() function me parameter pass krte hai
# contours ke fit ellipse ke parameters ko specify krne ke liye fitEllipse() function me parameter pass krte hai
# contours ke fit line ke parameters ko specify krne ke liye fitLine() function me parameter pass krte hai
# contours ke convex hull ke parameters ko specify krne ke liye convexHull() function me parameter pass krte hai
# contours ke bounding rectangle ke parameters ko specify krne ke liye boundingRect() function me parameter pass krte hai
# contours ke minimum enclosing circle ke parameters ko specify krne ke lie minEnclosingCircle() function me parameter pass krte hai
# contours ke moments ke parameters ko specify krne ke liye moments() function me parameter pass krte hai
# contours ke area ke parameters ko specify krne ke liye contourArea() function me parameter pass krte hai
# contours ke perimeter ke parameters ko specify krne ke liye arcLength() function me parameter pass krte hai       
# contours ke hierarchy ke parameters ko specify krne ke liye findContours() function me parameter pass krte hai
# contours ke image ke parameters ko specify krne ke liye findContours() function me parameter pass krte hai
# contours ke retrieval mode ke parameters ko specify krne ke liye findContours() function me parameter pass krte hai
# contours ke approximation method ke parameters ko specify krne ke liye findContours() function me

# %% [markdown]
# # Contour_fun.py

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# load image
img = cv2.imread('shapes.png')
# convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# apply binary thresholding
_, thresh = cv2.threshold(gray, 240, 255, cv2.THRESH_BINARY_INV)
# find contours
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# draw contours
cv2.drawContours(img, contours, -1, (0, 255, 0), 3)
# display image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show() #pass krte hai
