# %%
import cv2
import numpy as np
cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read() ## is return video frame is successful or not
    if not ret:
        break
    
    cv2.imshow('Live Feed', frame)
    # gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # cv2.imshow('Gray Live Feed', gray_frame)
    # blurred_frame = cv2.GaussianBlur(frame, (15, 15), 0)
    # cv2.imshow('Blurred Live Feed', blurred_frame)
    # edges = cv2.Canny(frame, 100, 200)
    # cv2.imshow('Edge Detected Live Feed', edges)
    # cv2.imshow('Live Feed', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()

# %%
import cv2
import numpy as np
cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read() ## is return video frame is successful or not
    if not ret:
        break
    ## convert image to gray scale
    img_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Live Feed', frame)
    # gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # cv2.imshow('Gray Live Feed', gray_frame)
    # blurred_frame = cv2.GaussianBlur(frame, (15, 15), 0)
    # cv2.imshow('Blurred Live Feed', blurred_frame)
    # edges = cv2.Canny(frame, 100, 200)
    # cv2.imshow('Edge Detected Live Feed', edges)
    # cv2.imshow('Live Feed', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()

# %%
## WEbcam recording with gray scale conversion
import cv2
import numpy as np
cap = cv2.VideoCapture(0)
# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi', fourcc, 20.0, (640, 480), isColor=False)
while True:
    ret, frame = cap.read() ## is return video frame is successful or not
    if not ret:
        break
    ## convert image to gray scale
    img_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Live Feed', frame)
    # Write the gray frame
    out.write(img_gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@0.830] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.895] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.929] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.963] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.995] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.029] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.062] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.095] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.128] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.162] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.194] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.231] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# ...
